# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
## Read the dataset
df = pd.read_csv('height-weight.csv')
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
plt.scatter(df['Height'],df['Weight'])
plt.xlabel('Height')
plt.ylabel('Weight')
# Out:
# Text(0, 0.5, 'Weight')

# %%
# Dividing the features
X = df[['Weight']]
y = df['Height']

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.2,random_state=42)

# %%
# standardize the data
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X_train_scale = scalar.fit_transform(X_train)
X_test_scale = scalar.transform(X_test)

# %%
# train the model
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
lr.fit(X_train_scale,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([0.17241379])

# %%
lr.intercept_
# Out:
# np.float64(154.60344827586206)

# %%
y_pred_test = lr.predict(X_test_scale)
y_pred_test
# Out:
# array([168.05172414, 168.05172414, 162.36206897, 170.98275862,
#        165.81034483, 172.70689655, 164.60344828, 171.84482759,
#        168.05172414, 162.87931034, 170.98275862, 162.36206897,
#        164.94827586, 166.67241379, 167.70689655, 163.22413793,
#        164.25862069, 167.01724138, 170.12068966])

# %%
#metrics
from sklearn.metrics import mean_absolute_error, r2_score
mae = mean_absolute_error(y_test, y_pred_test)
r2 = r2_score(y_test, y_pred_test)
print(mae)
print(r2)
# Out:
# 16.218693284936474
# -0.016791669493047
